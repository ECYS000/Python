# %% [markdown]
# <a href="https://colab.research.google.com/github/ECYS000/Python/blob/main/Aula4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Revisao aula 3

dados_salarios_programadores = {
    'UF': ['MS', 'RJ ', 'SP', 'SC', 'RS', 'BA'],
    'Quantidade': [100, 2000, 10000, 100, 1500, 700],
    'Salario': [1200, 4000, 6000, 4000, 5000, 2000]
    }

    # Quero mostrar o UF 'BA' junto com Salario

uf_BA = dados_salarios_programadores ['UF'][5]
salario_BA = dados_salarios_programadores ['Salario'][5]

print("DF: %s - Salario: %s" % (uf_BA, salario_BA))
# Out:
# DF: BA - Salario: 2000

# %%
import pandas as pd

tabela = pd.DataFrame(dados_salarios_programadores)

# %%
tabela.sort_values(by=['Salario'], ascending = False)
# Out:
#     UF  Quantidade  Salario
# 2   SP       10000     6000
# 4   RS        1500     5000
# 1  RJ         2000     4000
# 3   SC         100     4000
# 5   BA         700     2000
# 0   MS         100     1200

# %%
import pandas as pd

# Importação de dados sobre escolaridade ibge
url_arquivo_csv = 'https://raw.githubusercontent.com/lucasgian/python_2/main/escolarizac%CC%A7a%CC%83o.csv'
dados_escolaridade = pd.read_csv(url_arquivo_csv)

pd.DataFrame(dados_escolaridade)
# Out:
#    periodo  valor
# 0     2016   99.2
# 1     2017   99.2
# 2     2018   99.3
# 3     2019   99.7
# 4     2022   99.4

# %%
# Importação de dados sobre renda ibge

url_arquivo_csv = 'https://raw.githubusercontent.com/lucasgian/python_2/main/pib-per-capita-r.csv'
dados_renda = pd.read_csv(url_arquivo_csv)
dados_renda.rename(columns = { 'valor': 'renda'}, inplace = True)

pd.DataFrame(dados_renda)
# Out:
#     periodo     renda
# 0      2009  17271.34
# 1      2010  19938.60
# 2      2011  22259.91
# 3      2012  24278.35
# 4      2013  26657.54
# 5      2014  28648.74
# 6      2015  29466.85
# 7      2016  30558.75
# 8      2017  31843.95
# 9      2018  33593.82
# 10     2019  35161.70
# 11     2020  35935.69

# %%
# Quero juntar os dados de escolatidade e renda em uma tabela só

dados_juntos = pd.merge(dados_escolaridade, dados_renda, on = 'periodo')

pd.DataFrame(dados_juntos)
# Out:
#    periodo  valor     renda
# 0     2016   99.2  30558.75
# 1     2017   99.2  31843.95
# 2     2018   99.3  33593.82
# 3     2019   99.7  35161.70

# %%
import matplotlib.pyplot as plt

indicacao = dados_juntos['periodo']

fig, ax = plt.subplots()

ax.pie(dados_juntos['valor'], labels=indicacao)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fcf55c02080>,
#   <matplotlib.patches.Wedge at 0x7fcf55c02020>,
#   <matplotlib.patches.Wedge at 0x7fcf55c02620>,
#   <matplotlib.patches.Wedge at 0x7fcf55c019f0>],
#  [Text(0.7787393076157626, 0.7768945171476773, '2016'),
#   Text(-0.7750453564850149, 0.7805797175119376, '2017'),
#   Text(-0.7818042186782032, -0.7738101599597698, '2018'),
#   Text(0.7756620092308572, -0.7799669527845073, '2019')])
